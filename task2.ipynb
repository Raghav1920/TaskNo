# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np 
import seaborn as sns

# %%
df= pd.read_csv("advertising.csv")
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
print(df.shape)
print(df.columns)
df.tail()
# Out:
# (200, 4)
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.isna().values.any()
# Out:
# False

# %%
sns.scatterplot( x= df['TV'], y= df['Sales'])
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
sns.scatterplot( x= df['Radio'], y= df['Sales'], color ='red')
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
sns.scatterplot( x= df['Newspaper'], y= df['Sales'], color ='green')
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
plt.figure(figsize=(10,6),dpi=120)
plt.subplot(221)
plt.hist(df['TV'], color='yellow')
plt.title('TV')

plt.figure(figsize=(10,6),dpi=120)
plt.subplot(222)
plt.hist(df['Radio'], color='red')
plt.title('Radio')

plt.figure(figsize=(10,6),dpi=120)
plt.subplot(223)
plt.hist(df['Newspaper'], color='blue')
plt.title('Newspaper')

plt.figure(figsize=(10,6),dpi=120)
plt.subplot(224)
plt.hist(df['Sales'], color='green')
plt.title('Sales')
# Out:
# Text(0.5, 1.0, 'Sales')

# %%
sns.heatmap(df.corr(), annot=True, fmt= '.2f')
plt.title('Correlation of advertising with sales')
# Out:
# Text(0.5, 1.0, 'Correlation of advertising with sales')

# %%
x = df[['TV']]
y = df[['Sales']]

# %%
from sklearn.model_selection import train_test_split
x_train , x_test,y_train,y_test= train_test_split(x,y,test_size= 0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lg = LinearRegression()
lg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_train_pred = lg.predict(x_train)
print(x_train_pred)
# Out:
# [[ 9.1709017 ]
#  [ 8.87695647]
#  [14.94093769]
#  [18.57170561]
#  [18.88742456]
#  [12.75267876]
#  [ 7.63041096]
#  [ 8.08221567]
#  [14.0046677 ]
#  [12.85610393]
#  [13.1391623 ]
#  [19.65494821]
#  [20.97770175]
#  [17.22717836]
#  [ 9.59548926]
#  [10.55353297]
#  [23.10608294]
#  [16.55219302]
#  [18.18522207]
#  [ 7.55964637]
#  [21.59825279]
#  [17.91849399]
#  [19.0561709 ]
#  [15.18044861]
#  [16.48687185]
#  [19.01262345]
#  [21.46216703]
#  [16.0622843 ]
#  [12.62747986]
#  [11.31561319]
#  [17.22717836]
#  [14.47280269]
#  [22.06094435]
#  [23.296603  ]
#  [12.39885579]
#  [13.1391623 ]
#  [21.06479663]
#  [18.27231695]
#  [20.23195181]
#  [17.70620021]
#  [17.56467103]
#  [12.04503283]
#  [ 9.50295094]
#  [ 9.24166629]
#  [ 7.87536532]
#  [20.18840437]
#  [ 8.09854596]
#  [18.63158334]
#  [ 8.55579409]
#  [16.79714737]
#  [18.424733  ]
#  [10.76038331]
#  [15.31109094]
#  [14.20607461]
#  [12.28998719]
#  [22.22424726]
#  [22.23513412]
#  [ 7.58686352]
# ...

# %%
print(y_train)
# Out:
#      Sales
# 134   10.8
# 66    11.0
# 26    15.0
# 113   20.9
# 168   17.1
# ..     ...
# 67    13.4
# 192    5.9
# 117    9.4
# 47    23.2
# 172    7.6
#
# [160 rows x 1 columns]

# %%
print(lg.coef_)
print(lg.intercept_)
# Out:
# [[0.0544343]]
# [7.16227597]

# %%
x_test_pred = lg.predict(x_test)
print(x_test_pred)
# Out:
# [[10.92912965]
#  [ 9.88399105]
#  [12.08313684]
#  [22.93189318]
#  [16.42699412]
#  [10.22148373]
#  [ 7.63585439]
#  [20.23195181]
#  [ 8.45781235]
#  [17.91849399]
#  [21.38595901]
#  [11.90894708]
#  [15.68668762]
#  [17.38503783]
#  [11.32105662]
#  [13.70527904]
#  [21.62002651]
#  [ 7.20037998]
#  [11.22851831]
#  [18.77855596]
#  [22.81758114]
#  [14.7994085 ]
#  [16.6937222 ]
#  [14.33127351]
#  [10.07451111]
#  [13.86313851]
#  [16.17659633]
#  [18.32130782]
#  [19.35555956]
#  [ 8.52857694]
#  [10.85292163]
#  [17.98925858]
#  [22.44198446]
#  [20.3190467 ]
#  [ 7.88080875]
#  [ 8.18019741]
#  [10.40656035]
#  [17.00399772]
#  [10.88558221]
#  [ 8.52313351]]

# %%
print(y_test)
# Out:
#      Sales
# 18    11.3
# 170    8.4
# 107   12.0
# 98    25.4
# 177   16.7
# 182    8.7
# 5      7.2
# 146   18.2
# 12     9.2
# 152   16.6
# 61    24.2
# 125   10.6
# 180   15.5
# 154   20.6
# 80    11.8
# 7     13.2
# 33    17.4
# 130    1.6
# 37    14.7
# 74    17.0
# 183   26.2
# 145   10.3
# 45    16.1
# 159   12.9
# 60     8.1
# 123   15.2
# 179   17.6
# 185   22.6
# 122   16.6
# 44     8.5
# 16    12.5
# 55    23.7
# 150   16.1
# 111   21.8
# 22     5.6
# 189    6.7
# 129    9.7
# 4     17.9
# 83    13.6
# 106    7.2
